# %% [markdown]
#  # geocode with google maps

# %% [markdown]
#  Here we geocode the locations of the FOI NON TRADS. THE OUTPUT TABLE IS 'GOOGLE_geocoded_addresses.csv'

# %%
import googlemaps
import pandas as pd

# %%
import math 
def distance(lat1, lon1, lat2, lon2):
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])

    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 6371 * 1000  # Radius of earth in meters
    return c * r

# %%
df = pd.read_csv('/Users/gracecolverd/Library/CloudStorage/GoogleDrive-grace.bcolverd@gmail.com/My Drive/Non_Trads_FOI/non_trad_FOI/7_FOI_data_with_class/FOI_processed_mapping.csv')

# %% [markdown]
# DO not run below cell again - will charge you

# %%
# # set up the Google Street View API endpoint URL and parameters
# API_KEY = 'AIzaSyA8ICcAbeujUreL2eLATj0FD2CRLKIkQQk'  # replace with your Google API key
# IMG_SIZE = '640x640'  # set the size of the downloaded images
# PITCH = '10'

# # Set up Google Maps API client
# gmaps = googlemaps.Client(key=API_KEY)


# # Define function to geocode a single address
# def geocode_address(address):
#     try:
#         # Use Google Maps API geocode method to get lat/long coordinates for the address
#         geocode_result = gmaps.geocode(address)
#         lat = geocode_result[0]['geometry']['location']['lat']
#         lng = geocode_result[0]['geometry']['location']['lng']
#         return pd.Series({'Latitude': lat, 'Longitude': lng})
#     except:
#         # If geocoding fails, return NaN values for lat/long
#         return pd.Series({'Latitude': None, 'Longitude': None})

# # Apply the geocode_address function to each row of the dataframe and append the resulting lat/long values to the dataframe
# df[['Latitude', 'Longitude']] = df['Address'].apply(geocode_address)

# # Write the updated dataframe to a new CSV file
# df.to_csv('GOOGLE_geocoded_addresses.csv', index=False)

# %%
df.head()
# Out:
#    Unnamed: 0     UPRN                     Address raw_Construction_type  \
# 0        3843  1019030  36 HERTFORD ROAD Kettering               cornish
# 1        3844  1019052  38 HERTFORD ROAD Kettering               cornish
# 2        3845  1019063  40 HERTFORD ROAD Kettering               cornish
# 3        3846  1019085  42 HERTFORD ROAD Kettering               cornish
# 4        3847  1019096  44 HERTFORD ROAD Kettering               cornish
#
#   Processed_Construction_Type Other_Attributes  BRE_mapping_matches BRE_Class  \
# 0                     cornish              NaN  Cornish Unit Type I       PCC
# 1                     cornish              NaN  Cornish Unit Type I       PCC
# 2                     cornish              NaN  Cornish Unit Type I       PCC
# 3                     cornish              NaN  Cornish Unit Type I       PCC
# 4                     cornish              NaN  Cornish Unit Type I       PCC
#
#     Latitude  Longitude
# 0  52.380445  -0.715830
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# 5 usd per 1k; 26k = 130 USD

# %%
df[df['Latitude'].isna()]
# Out:
#      UPRN                        Address raw_Construction_type  \
# 686   NaN   1 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 687   NaN   2 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 688   NaN   3 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 689   NaN   4 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 690   NaN   5 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 691   NaN   6 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 692   NaN   7 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 693   NaN   8 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 694   NaN   9 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 695   NaN  10 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 696   NaN  11 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
# 697   NaN  12 BRAMALL HOUSE BRAMALL LANE       wimpey no fines
#
#     Processed_Construction_Type  \
# 686             wimpey no fines
# 687             wimpey no fines
# 688             wimpey no fines
# ...

# %%
old_df = pd.read_csv('geocoded_addresses1.csv')

# %%
old_df[old_df['Latitude'].isna()]
# Out:
#       Unnamed: 0  UPRN                                     Address  \
# 142         3985   NaN   3 The Meads Weston Rhyn Oswestry SY10 7SH
# 143         3986   NaN   4 The Meads Weston Rhyn Oswestry SY10 7SH
# 144         3987   NaN   8 The Meads Weston Rhyn Oswestry SY10 7SH
# 145         3988   NaN   9 The Meads Weston Rhyn Oswestry SY10 7SH
# 146         3989   NaN  10 The Meads Weston Rhyn Oswestry SY10 7SH
# ...          ...   ...                                         ...
# 795         4796   NaN                8 TWICKENHAM RISE DARLINGTON
# 1227        5228   NaN     26 SEAL CRAIG GARDENS ABERDEEN AB12 3SH
# 1228        5229   NaN     40 SEAL CRAIG GARDENS ABERDEEN AB12 3SH
# 1229        5230   NaN     41 SEAL CRAIG GARDENS ABERDEEN AB12 3SH
# 1230        5231   NaN     43 SEAL CRAIG GARDENS ABERDEEN AB12 3SH
#
#      raw_Construction_type Processed_Construction_Type  \
# 142                cornish                     cornish
# ...

# %%
old_df
# Out:
#       Unnamed: 0       UPRN                             Address  \
# 0           3843  1019030.0          36 HERTFORD ROAD Kettering
# 1           3844  1019052.0          38 HERTFORD ROAD Kettering
# 2           3845  1019063.0          40 HERTFORD ROAD Kettering
# 3           3846  1019085.0          42 HERTFORD ROAD Kettering
# 4           3847  1019096.0          44 HERTFORD ROAD Kettering
# ...          ...        ...                                 ...
# 1295        5296        NaN  16 WAGLEY PARADE ABERDEEN AB21 9WG
# 1296        5297        NaN  17 WAGLEY PARADE ABERDEEN AB21 9UB
# 1297        5298        NaN  18 WAGLEY PARADE ABERDEEN AB21 9WG
# 1298        5299        NaN  22 WAGLEY PARADE ABERDEEN AB21 9WG
# 1299        5300        NaN  24 WAGLEY PARADE ABERDEEN AB21 9WG
#
#      raw_Construction_type Processed_Construction_Type  \
# 0                  cornish                     cornish
# 1                  cornish                     cornish
# ...

# %%
actual = 52.380438, -0.715695

# %%
#google 
distance( *actual, 52.380445, -0.715830)
# Out:
# 9.196140406853921

# %%
#open street maps 
distance( *actual, 52.380558, -0.715714)
# Out:
# 13.405566856072234
